# %% [markdown]
# <a href="https://colab.research.google.com/github/brahmani2008/Nasscom-lab/blob/main/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python!")
if True:
    print("This is indented correctly.")
else:
    print("This won't run.")
# Out:
# Hello, Python!
# This is indented correctly.

# %%
name = "Alice"
age = 25
height = 5.6
print("Name:", name)
print("Age:", age)
print("Height:", height)
name = 123
print("New value of name:", name)
# Out:
# Name: Alice
# Age: 25
# Height: 5.6
# New value of name: 123

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
b = 3.14
print(type(b))
# Out:
# <class 'float'>

# %%
c = "Python"
print(type(c))
d = True
print(type(d))
e = [1, 2, 3, "four"]
print(type(e), e)
f = {"name": "Alice", "age": 25}
print(type(f), f)
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'Alice', 'age': 25}

# %%
print("Welcome to Python I/O!")
# Out:
# Welcome to Python I/O!

# %%
user_name = input("Enter your name: ")
print("Hello,", user_name)
# Out:
# Enter your name: S.Brahmani
# Hello, S.Brahmani

# %%
user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Enter your age: 17
# You will be 18 next year.
